# %% [markdown]
# # Imports

# %%
import torch
import pandas as pd
import torch.optim as optim
import numpy as np
import torch.nn as nn 
import torch.nn.functional as F 
import matplotlib.pyplot as plt
# import operator
# from datetime import datetime
from sklearn.model_selection import train_test_split
from utils import *
from models.rnn import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Define CUDA

# %%
device = 'mps' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Load Dataset

# %%
#stocks dataset for Altaba Inc
dataset = pd.read_csv('data/bitcoin_final.csv')
display(dataset)
dataset['date'] = dataset['date'].apply(lambda x: string_to_time(x))
bit_value =  dataset[['price']]
# Out:
#             date         price  13.tweets_neg  1.gt_bitcoin  10.news_senti  \
# 0     2018-03-01  10929.765497       0.043355     29.428571       0.179275
# 1     2018-03-02  11095.091956       0.065677     29.285714       0.162121
# 2     2018-03-03  11494.898944       0.050288     29.142857       0.146234
# 3     2018-03-04  11516.383566       0.055335     29.000000       0.134706
# 4     2018-03-05  11527.568787       0.045240     29.571429       0.124035
# ...          ...           ...            ...           ...            ...
# 1761  2022-12-26  16908.948430       0.047236     17.714286      -0.100316
# 1762  2022-12-27  16706.459710       0.051911     17.428571      -0.099167
# 1763  2022-12-28  16549.983266       0.053312     17.142857      -0.088863
# 1764  2022-12-29  16641.444864       0.050335     16.857143      -0.083155
# 1765  2022-12-30  16603.751953       0.046048     16.571429      -0.082299
#
#       12.tweets_pos  14.twitter_btccrash_pos  2.gt_Buy_Bitcoin  7.s&p_twitter  \
# 0          0.151006                 0.215653         19.000000      99.350000
# 1          0.133858                 0.185810         19.000000      99.950000
# 2          0.138788                 0.136385         19.000000     100.296667
# 3          0.147588                 0.162947         19.000000     100.643333
# 4          0.133230                 0.126600         18.857143     100.990000
# ...             ...                      ...               ...            ...
# 1761       0.103354                 0.126526         44.000000     154.027500
# 1762       0.121210                 0.090167         43.000000     154.050000
# 1763       0.105740                 0.084077         42.000000     152.360000
# 1764       0.123247                 0.103692         41.000000     154.400000
# 1765       0.113528                 0.080154         40.000000     153.750000
#
#       8.CBDC_uncertainty  15.twitter_btccrash_neg  6.gt_covid  \
# 0             100.940928                 0.130917         0.0
# 1             101.036708                 0.146667         0.0
# 2             101.023647                 0.202692         0.0
# 3             101.010586                 0.201579         0.0
# 4             100.997525                 0.172333         0.0
# ...                  ...                      ...         ...
# 1761          102.765109                 0.188474        11.0
# 1762          102.691097                 0.250583        11.0
# 1763          102.617084                 0.275923        11.0
# 1764          102.543072                 0.245385        11.0
# 1765          102.469060                 0.241846        11.0
#
#       5.gt_Ukraine_war  9.CBDC_atten  3.gt_Sell_Bitcoin  4.gt_ethereum  \
# 0             0.000000    100.431902          16.000000      12.428571
# 1             0.000000    100.464187          16.000000      12.285714
# 2             0.000000    100.439308          16.000000      12.142857
# 3             0.000000    100.414430          16.000000      12.000000
# 4             0.000000    100.389551          16.000000      11.857143
# ...                ...           ...                ...            ...
# 1761         11.857143    101.536812           9.428571       4.571429
# 1762         11.714286    101.472052           9.857143       5.142857
# 1763         11.571429    101.407292          10.285714       5.714286
# 1764         11.428571    101.342532          10.714286       6.285714
# 1765         11.285714    101.277772          11.142857       6.857143
#
#       11.fear&greed
# 0              38.0
# 1              47.0
# 2              56.0
# 3              44.0
# 4              55.0
# ...             ...
# 1761           28.0
# 1762           27.0
# 1763           28.0
# 1764           28.0
# 1765           28.0
#
# [1766 rows x 17 columns]

# %%
#close value is stock price at the end of that day
plt.figure(figsize=(12, 6))
plt.plot(list(range(len(dataset))), dataset['price'])
plt.xlabel('Time')
plt.ylabel('bitcoin Price')
plt.show()

# %% [markdown]
# # Proprocess Dataset

# %%
#normalize dataset and keep track of close value
min_max_dictionary = min_max_dic(dataset)
cols = list(dataset.columns.values)
bit_dataset = dataset[[cols[0]]+cols[2:]+[cols[1]]]
display(bit_dataset)
# Out:
#           date  13.tweets_neg  1.gt_bitcoin  10.news_senti  12.tweets_pos  \
# 0     0.000000       0.155574      0.232919       0.943870       0.433966
# 1     0.000567       0.314442      0.231366       0.924846       0.353774
# 2     0.001133       0.204913      0.229814       0.907228       0.376829
# 3     0.001700       0.240838      0.228261       0.894443       0.417984
# 4     0.002266       0.168987      0.234472       0.882609       0.350837
# ...        ...            ...           ...            ...            ...
# 1761  0.997734       0.183196      0.105590       0.633804       0.211127
# 1762  0.998300       0.216468      0.102484       0.635078       0.294626
# 1763  0.998867       0.226437      0.099379       0.646506       0.222281
# 1764  0.999433       0.205251      0.096273       0.652835       0.304154
# 1765  1.000000       0.174737      0.093168       0.653784       0.258701
#
#       14.twitter_btccrash_pos  2.gt_Buy_Bitcoin  7.s&p_twitter  \
# 0                    0.487902          0.129032       0.123794
# 1                    0.420384          0.129032       0.130298
# 2                    0.308562          0.129032       0.134056
# 3                    0.368659          0.129032       0.137814
# 4                    0.286425          0.127496       0.141572
# ...                       ...               ...            ...
# 1761                 0.286259          0.397849       0.716504
# 1762                 0.203997          0.387097       0.716748
# 1763                 0.190219          0.376344       0.698428
# 1764                 0.234598          0.365591       0.720542
# 1765                 0.181344          0.354839       0.713496
#
#       8.CBDC_uncertainty  15.twitter_btccrash_neg  6.gt_covid  \
# 0               0.239365                 0.198660        0.00
# 1               0.253333                 0.222559        0.00
# 2               0.251429                 0.307576        0.00
# 3               0.249524                 0.305886        0.00
# 4               0.247619                 0.261507        0.00
# ...                  ...                      ...         ...
# 1761            0.505397                 0.286000        0.11
# 1762            0.494603                 0.380248        0.11
# 1763            0.483809                 0.418700        0.11
# 1764            0.473016                 0.372359        0.11
# 1765            0.462222                 0.366990        0.11
#
#       5.gt_Ukraine_war  9.CBDC_atten  3.gt_Sell_Bitcoin  4.gt_ethereum  \
# 0             0.000000      0.132394           0.134021       0.115440
# 1             0.000000      0.137405           0.134021       0.113997
# 2             0.000000      0.133544           0.134021       0.112554
# 3             0.000000      0.129683           0.134021       0.111111
# 4             0.000000      0.125822           0.134021       0.109668
# ...                ...           ...                ...            ...
# 1761          0.118571      0.303870           0.066274       0.036075
# 1762          0.117143      0.293819           0.070692       0.041847
# 1763          0.115714      0.283769           0.075110       0.047619
# 1764          0.114286      0.273719           0.079529       0.053391
# 1765          0.112857      0.263668           0.083947       0.059163
#
#       11.fear&greed     price
# 0          0.366667  0.119712
# 1          0.466667  0.122284
# 2          0.566667  0.128506
# 3          0.433333  0.128840
# 4          0.555556  0.129014
# ...             ...       ...
# 1761       0.255556  0.212754
# 1762       0.244444  0.209603
# 1763       0.255556  0.207168
# 1764       0.255556  0.208591
# 1765       0.255556  0.208004
#
# [1766 rows x 17 columns]

# %%
#split data into training and testing components
from utils import *
x_train, y_train, x_test, y_test = split_data(dataset, 20)
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()
x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# torch.Size([1397, 19, 17])
# torch.Size([1397])
# torch.Size([349, 19, 17])
# torch.Size([349])

# %% [markdown]
# # Initialize Hyperparameters

# %%
input_size = 17
hidden_dim = 64
num_layers = 3
output_dim = 1
epochs = 300

# %% [markdown]
# # Define Model (GRU)

# %%
model = LSTM(input_size, hidden_dim, num_layers, output_dim).to(device)
loss_func = nn.MSELoss(reduction='mean').to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Train Model

# %%
train_loss = []
min_loss = np.Inf

for epoch in range(epochs):
    #zero out gradients
    optimizer.zero_grad()

    pred = model(x_train.to(device)).squeeze()
    loss = loss_func(pred, y_train.to(device))
    train_loss.append(loss.item())
    # print('Epoch {},    Loss: {:.10f}\n'.format(epoch, loss.item()))
    model.eval()
    pred = model(x_test.to(device)).squeeze()
    val_loss = loss_func(pred, y_test.to(device)).item()
    
    #keep track of lowest loss and save as best model
    if val_loss < min_loss:
        print('     train: {:.10f} val Loss: {:.10f} ----> {:.10f}\n'.format(train_loss[-1],min_loss,val_loss ))
        torch.save(model.state_dict(), 'best_model.pt')
        min_loss = val_loss
        model.train()

    #back propogate
    loss.backward()
    optimizer.step()
# Out:
#      train: 0.2124822140 val Loss: inf ----> 0.0377419516
#
#      train: 0.1914511025 val Loss: 0.0377419516 ----> 0.0295184217
#
#      train: 0.1708297729 val Loss: 0.0295184217 ----> 0.0226003677
#
#      train: 0.1500726640 val Loss: 0.0226003677 ----> 0.0171015933
#
#      train: 0.1289867312 val Loss: 0.0171015933 ----> 0.0135670928
#
#      train: 0.1077533886 val Loss: 0.0135670928 ----> 0.0131584946
#
#      train: 0.0182852373 val Loss: 0.0131584946 ----> 0.0128746182
#
#      train: 0.0180851687 val Loss: 0.0128746182 ----> 0.0120833255
#
#      train: 0.0180096496 val Loss: 0.0120833255 ----> 0.0116159664
#
#      train: 0.0177977774 val Loss: 0.0116159664 ----> 0.0115739284
#
#      train: 0.0109876785 val Loss: 0.0115739284 ----> 0.0113825426
#
#      train: 0.0107125537 val Loss: 0.0113825426 ----> 0.0112574724

# %%
lossfn=nn.CrossEntropyLoss()
train_loss = []
min_loss = np.Inf

for epoch in range(epochs):
    #zero out gradients
    optimizer.zero_grad()

    pred = model(x_train.to(device)).squeeze()
    loss = loss_func(pred, y_train.to(device))
    train_loss.append(loss.item())
    # print('Epoch {},    Loss: {:.10f}\n'.format(epoch, loss.item()))
    model.eval()
    pred = model(x_test.to(device)).squeeze()
    val_loss = loss_func(pred, y_test.to(device)).item()
    
    #keep track of lowest loss and save as best model
    if val_loss < min_loss:
        print('     train: {:.10f} val Loss: {:.10f} ----> {:.10f}\n'.format(train_loss[-1],min_loss,val_loss ))
        torch.save(model.state_dict(), 'best_model.pt')
        min_loss = val_loss
        model.train()

    #back propogate
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Evaluating Model

# %%
#visualize loss throughout training
plt.figure(figsize=(12, 6))
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.plot(list(range(epochs)), train_loss)

# %% [markdown]
# # Load the Best Model

# %%
best_model = LSTM(input_size, hidden_dim, num_layers, output_dim).to(device)
best_model.load_state_dict(torch.load('best_model.pt'))
# Out:
# <All keys matched successfully>

# %%
#get predictions
lstm_predictions = model(x_test.to(device))
test_loss = loss_func(lstm_predictions.squeeze(), y_test.to(device))
lstm_predictions = lstm_predictions.squeeze().tolist()
print(lstm_predictions)
# Out:
# [0.18169310688972473, 0.20048289000988007, 0.21020101010799408, 0.21466678380966187, 0.24389325082302094, 0.23825228214263916, 0.23546279966831207, 0.18407461047172546, 0.12473903596401215, 0.12664976716041565, 0.16659890115261078, 0.17031355202198029, 0.20909984409809113, 0.22868023812770844, 0.255715012550354, 0.2654589116573334, 0.29854899644851685, 0.2774602174758911, 0.26788580417633057, 0.2705910801887512, 0.24036835134029388, 0.24832813441753387, 0.32919007539749146, 0.3878439664840698, 0.4892911911010742, 0.5068854093551636, 0.5572353601455688, 0.5621169209480286, 0.5462433099746704, 0.49920201301574707, 0.493971586227417, 0.5424253344535828, 0.6387159824371338, 0.7336044311523438, 0.7635074257850647, 0.681659460067749, 0.6629765033721924, 0.737917423248291, 0.7340772747993469, 0.7015492916107178, 0.7394165992736816, 0.7255880832672119, 0.7299462556838989, 0.7327481508255005, 0.7429672479629517, 0.7024194598197937, 0.8761285543441772, 0.9353859424591064, 0.8550760746002197, 0.7605693340301514, 0.6692518591880798, 0.5912013053894043, 0.6005721092224121, 0.5668185949325562, 0.5810750722885132, 0.5931555032730103, 0.5272238850593567, 0.4968884289264679, 0.46137046813964844, 0.4465961158275604, 0.4574533700942993, 0.48130860924720764, 0.4854508340358734, 0.4820297956466675, 0.5109900236129761, 0.5270588994026184, 0.5196911096572876, 0.4906051754951477, 0.4979551434516907, 0.5712810754776001, 0.638696551322937, 0.6639618873596191, 0.6686846017837524, 0.7357444763183594, 0.7421589493751526, 0.7042186856269836, 0.6699796915054321, 0.6751828193664551, 0.6743287444114685, 0.6494873762130737, 0.6778225898742676, 0.6843821406364441, 0.6743590235710144, 0.5569885969161987, 0.503903865814209, 0.4888392686843872, 0.5178832411766052, 0.4847941994667053, 0.39619478583335876, 0.39569225907325745, 0.4297580122947693, 0.4189499020576477, 0.4226500689983368, 0.41912123560905457, 0.3950386643409729, 0.37328726053237915, 0.40927547216415405, 0.3908972144126892, 0.36574113368988037, 0.3657339811325073, 0.38156309723854065, 0.37062036991119385, 0.38104379177093506, 0.3744864761829376, 0.3905743360519409, 0.38331085443496704, 0.32240813970565796, 0.32184797525405884, 0.3827132284641266, 0.4161701798439026, 0.39948344230651855, 0.3791596591472626, 0.37253379821777344, 0.3601127862930298, 0.31712889671325684, 0.24313344061374664, 0.21543921530246735, 0.19818629324436188, 0.21570177376270294, 0.22308459877967834, 0.20596741139888763, 0.19993779063224792, 0.24723948538303375, 0.23690803349018097, 0.20577940344810486, 0.21299944818019867, 0.232615128159523, 0.23999108374118805, 0.24179469048976898, 0.22689716517925262, 0.21797488629817963, 0.20568309724330902, 0.20491069555282593, 0.20884856581687927, 0.21133597195148468, 0.22124086320400238, 0.23044706881046295, 0.2379736453294754, 0.24704067409038544, 0.22807593643665314, 0.19475851953029633, 0.20468033850193024, 0.20961439609527588, 0.216367706656456, 0.23571398854255676, 0.2585637867450714, 0.24985767900943756, 0.2390672117471695, 0.23313544690608978, 0.22942708432674408, 0.19042934477329254, 0.16719108819961548, 0.15025390684604645, 0.14438144862651825, 0.15275302529335022, 0.11657506227493286, 0.10394348204135895, 0.13204199075698853, 0.1574840247631073, 0.15797722339630127, 0.16822996735572815, 0.1708691269159317, 0.19484741985797882, 0.21011905372142792, 0.2033756524324417, 0.17816351354122162, 0.16934765875339508, 0.16642332077026367, 0.1654984951019287, 0.19697026908397675, 0.18780405819416046, 0.20261834561824799, 0.24376104772090912, 0.251067578792572, 0.23455151915550232, 0.2429398149251938, 0.27574312686920166, 0.2987610995769501, 0.2772238850593567, 0.23527713119983673, 0.2225751131772995, 0.24056565761566162, 0.24493847787380219, 0.2780314087867737, 0.2993321120738983, 0.3082779049873352, 0.3540950417518616, 0.37997421622276306, 0.3801943063735962, 0.39063361287117004, 0.3836243748664856, 0.3567652106285095, 0.3425224721431732, 0.33972102403640747, 0.3640265464782715, 0.386526226997 ...

# %% [markdown]
# # Reverse Normalize

# %%
min = min_max_dictionary['price'][0]
max = min_max_dictionary['price'][1]

#reverse normalize predictions and dataset values
lstm_predictions = [reverse_normalize(x, min, max) for x in np.array(lstm_predictions)]

# stock_value = [reverse_normalize(x, min, max) for x in np.array(bit_value)]
# print(lstm_predictions)

# %% [markdown]
# # Visualizing and Testing Model

# %%
plt.figure(figsize=(12, 6))
plt.plot([i for i in range(x_train.size(0))], bit_value[:x_train.size(0)], color='b', label='trained values')

#plot test range and predictions by the GRU
time_values_actual = list(range(x_train.size(0), len(bit_value)))
time_values_pred = list(range(x_train.size(0), x_train.size(0) + y_test.size(0)))
plt.xlabel('Time')
plt.ylabel('Stock Values')
plt.plot(time_values_actual, bit_value[-len(time_values_actual):], color='r', label='actual values')
plt.plot(time_values_pred[3:], lstm_predictions[3:], color='g', linewidth=2, label='predicted values')

plt.show()
